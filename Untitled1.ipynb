# %% [markdown]
# <a href="https://colab.research.google.com/github/Knight451/ps1/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-70cef299-4dd6-47f5-935f-3ef4b11f8c2e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-70cef299-4dd6-47f5-935f-3ef4b11f8c2e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive
import pandas as pd

# Mount Google Drive
# drive.mount('/https://drive.google.com/drive/home')

# Specify the path to the CSV file
path = '/content/Criminal Justice Data Dashboard - defendant charges 2017.xlsx'
from google.colab import drive
import pandas as pd

# Mount Google Drive
# drive.mount('/https://drive.google.com/drive/home')

# Specify the path to the CSV file
path = '/content/Criminal Justice Data Dashboard - defendant charges 2017.xlsx'

# Read the file into a pandas DataFrame
df = pd.read_excel(path)
print(df)
# Out:
#                 ID      County  Arrest Year Arrest Month  \
# 0       XXX2C2C7QA    Atlantic         2017         July
# 1       XXX2C2C7QA    Atlantic         2017         July
# 2       XXX2C2C7QA    Atlantic         2017         July
# 3       XXX2C2C7QA    Atlantic         2017         July
# 4       XXX2C2CC6C  Cumberland         2017     February
# ...            ...         ...          ...          ...
# 346038  XXXXXWQ7WB  Cumberland         2017      October
# 346039  XXXXXWQ7WB  Cumberland         2017      October
# 346040  XXXXXWQ7WB  Cumberland         2017      October
# 346041  XXXXXWQ7WB  Cumberland         2017      October
# 346042  XXXXXWQWGB      Camden         2017     December
#
#                                  Race Age Range  Gender Offense Statute  \
# 0                               Black     55-64    Male     2C:35-5A(1)
# 1                               Black     55-64    Male     2C:35-5A(1)
# ...

# %%
from google.colab import drive
import pandas as pd

# Mount Google Drive
# drive.mount('/https://drive.google.com/drive/home')

# Specify the path to the CSV file
path = '/content/Criminal Justice Data Dashboard - fines fees restitution.xlsx'
from google.colab import drive
import pandas as pd

# Mount Google Drive
# drive.mount('/https://drive.google.com/drive/home')

# Specify the path to the CSV file
path = '/content/Criminal Justice Data Dashboard - fines fees restitution.xlsx'

# Read the file into a pandas DataFrame
df = pd.read_excel(path)
print(df)
# Out:
#                 ID  IT Automation Fee  Auto Theft Fine Amt  \
# 0       XXXXX7XGGB                  2                    0
# 1       XXXXX7NCGB                  2                    0
# 2       XXXXX7N8QB                  2                    0
# 3       XXXXX7GQNA                  2                    0
# 4       XXXXXC867B                  2                    0
# ...            ...                ...                  ...
# 360415  XXX6668CXE                  0                    0
# 360416  XXXW6XW72G                  0                    0
# 360417  XXXC2W672C                  0                    0
# 360418  XXXW87W6XB                  0                    0
# 360419  XXXWG2N77B                  0                    0
#
#         Drug Abuse Education Fund Fine  Drug Enforcement Rehab Fine  \
# 0                                   50                          500
# 1                                    0                            0
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

file_path_2021 = 'https://docs.google.com/spreadsheets/d/1K1B96IJ8getDiF5aK7E6L8SDlFcn8H3X/edit?gid=225598396#gid=225598396'  # Replace with your actual file path
file_path_2022 = 'https://docs.google.com/spreadsheets/d/1UUe7nTiqeqk8vMi4zREjUKYGOZh-_q9a/edit?usp=drive_web&ouid=104606677066800863579&rtpof=true'  # Replace with your actual file path
file_path_2023 = 'https://docs.google.com/spreadsheets/d/1UKbXIM-Emr6rY0c3qAMYlRdNOGuPl0yD/edit?usp=sharing&ouid=104606677066800863579&rtpof=true&sd=true'  # Replace with your actual file path

import pandas as pd

df_2021 = pd.read_excel(file_path_2021)
df_2022 = pd.read_excel(file_path_2022)
df_2023 = pd.read_excel(file_path_2023)
# Out:
# Mounted at /content/drive
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-29-9bd975e2f584> in <cell line: 0>()
#       8 import pandas as pd
#       9
# ---> 10 df_2021 = pd.read_excel(file_path_2021)
#      11 df_2022 = pd.read_excel(file_path_2022)
#      12 df_2023 = pd.read_excel(file_path_2023)
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
# ...
